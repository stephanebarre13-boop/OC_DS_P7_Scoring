# %%
import joblib

params = {
    "modele": "LightGBM",
    "seuil_optimal": 0.370,
    "cout_fn": 10,
    "cout_fp": 1
}

joblib.dump(params, r"C:\Users\Utilisateur\Desktop\MARS_PROJECT_7\artifacts\parametres_decision.joblib")
print(" Créé avec seuil =", params["seuil_optimal"])
# Out:
#  Créé avec seuil = 0.37
